# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import numpy
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# # Loading The Dataset

# %%
hrdata_df=pd.read_csv("C:/Users/Home/Downloads/Final dataset Attrition (1) (1).csv")
hrdata_df.head()
# Out:
#    Age Attrition BusinessTravel              Department  DistanceFromHome  \
# 0   37       Yes  Travel_Rarely  Research & Development                 2
# 1   21        No  Travel_Rarely  Research & Development                15
# 2   45        No  Travel_Rarely  Research & Development                 6
# 3   23        No  Travel_Rarely                   Sales                 2
# 4   22        No  Travel_Rarely  Research & Development                15
#
#    Gender  JobInvolvement  JobLevel                JobRole  JobSatisfaction  \
# 0    Male               2         1  Laboratory Technician                3
# 1    Male               3         1     Research Scientist                4
# 2    Male               3         3      Research Director                1
# 3    Male               3         1   Sales Representative                1
# 4  Female               3         1  Laboratory Technician                4
#
# ...

# %%
hrdata_df.shape
# Out:
# (1470, 33)

# %%
hrdata_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Age                      1470 non-null   int64
#  1   Attrition                1470 non-null   object
#  2   BusinessTravel           1470 non-null   object
#  3   Department               1470 non-null   object
#  4   DistanceFromHome         1470 non-null   int64
#  5   Gender                   1470 non-null   object
#  6   JobInvolvement           1470 non-null   int64
#  7   JobLevel                 1470 non-null   int64
#  8   JobRole                  1470 non-null   object
#  9   JobSatisfaction          1470 non-null   int64
#  10  MaritalStatus            1470 non-null   object
#  11  MonthlyIncome            1470 non-null   int64
#  12  NumCompaniesWorked       1470 non-null   int64
#  13  OverTime                 1470 non-null   object
# ...

# %%
hrdata_df.isnull().sum()
# Out:
# Age                        0
# Attrition                  0
# BusinessTravel             0
# Department                 0
# DistanceFromHome           0
# Gender                     0
# JobInvolvement             0
# JobLevel                   0
# JobRole                    0
# JobSatisfaction            0
# MaritalStatus              0
# MonthlyIncome              0
# NumCompaniesWorked         0
# OverTime                   0
# PercentSalaryHike          0
# PerformanceRating          0
# StockOptionLevel           0
# TotalWorkingYears          0
# TrainingTimesLastYear      0
# YearsAtCompany             0
# YearsSinceLastPromotion    0
# YearsWithCurrManager       0
# Higher_Education           0
# Date_of_Hire               0
# Status_of_leaving          0
# Mode_of_work               0
# Leaves                     0
# Absenteeism                0
# Work_accident              0
# Source_of_Hire             0
# Job_mode                   0
# dtype: int64

# %%
hrdata_df.drop(['Date_of_termination','Unnamed: 32'], axis=1, inplace=True)

# %%
hrdata_df.describe(include='object')
# Out:
#        Attrition BusinessTravel              Department Gender  \
# count       1470           1470                    1470   1470
# unique         2              3                       3      2
# top           No  Travel_Rarely  Research & Development   Male
# freq        1233           1043                     961    882
#
#                 JobRole MaritalStatus OverTime Higher_Education Date_of_Hire  \
# count              1470          1470     1470             1470         1470
# unique                9             3        2                4         1112
# top     Sales Executive       Married       No  Post-Graduation   17-02-2016
# freq                326           673     1054              387            5
#
#        Status_of_leaving Mode_of_work Work_accident Source_of_Hire  Job_mode
# count               1470         1470          1470           1470      1470
# unique                 5            2             2              4         3
# ...

# %%
hrdata_df.describe()
# Out:
#                Age  DistanceFromHome  JobInvolvement     JobLevel  \
# count  1470.000000       1470.000000     1470.000000  1470.000000
# mean     36.923810          9.192517        2.729932     2.063946
# std       9.135373          8.106864        0.711561     1.106940
# min      18.000000          1.000000        1.000000     1.000000
# 25%      30.000000          2.000000        2.000000     1.000000
# 50%      36.000000          7.000000        3.000000     2.000000
# 75%      43.000000         14.000000        3.000000     3.000000
# max      60.000000         29.000000        4.000000     5.000000
#
#        JobSatisfaction  MonthlyIncome  NumCompaniesWorked  PercentSalaryHike  \
# count      1470.000000    1470.000000         1470.000000        1470.000000
# mean          2.728571    6502.931293            2.693197          15.209524
# std           1.102846    4707.956783            2.498009           3.659938
# ...

# %% [markdown]
# # EDA and Data Visualisation

# %%
Attrition_Count=hrdata_df['Attrition'].value_counts()
print(Attrition_Count)
Attrition_Percent=hrdata_df['Attrition'].value_counts(normalize=True)
print(Attrition_Percent)
print("*"*125)
fig,ax=plt.subplots(1,1,figsize=(10,5))
hrdata_df['Attrition'].value_counts().plot(kind='pie',autopct="%.2f", shadow=True,startangle=90,labels=Attrition_Count.index, ax=ax)
plt.title("Attrition_Count")
#plt.legend(labels=labels, loc='upper right')
plt.show()
# Out:
# No     1233
# Yes     237
# Name: Attrition, dtype: int64
# No     0.838776
# Yes    0.161224
# Name: Attrition, dtype: float64
# *****************************************************************************************************************************

# %%
fig,ax=plt.subplots(1,1,figsize=(10,5))
sns.countplot(x="Attrition", data=hrdata_df, ax=ax)
plt.title("Attrition_Count")
plt.ylabel("Amount_of_Attrition")

for bars in ax.containers:
    ax.bar_label(bars)

# %% [markdown]
# # Analysis Of rating features

# %%
JobSatisfaction_Count=hrdata_df['JobSatisfaction'].value_counts()
print(JobSatisfaction_Count)
JobSatisfaction_Percent=hrdata_df['JobSatisfaction'].value_counts(normalize=True)
print(JobSatisfaction_Percent)
print("="*125)
JobInvolvement_Count=hrdata_df['JobInvolvement'].value_counts()
print(JobInvolvement_Count)
JobInvolvement_Percent=hrdata_df['JobInvolvement'].value_counts(normalize=True)
print(JobInvolvement_Percent)
print("*"*125)

fig,ax=plt.subplots(1,2,figsize=(10,5))
ax1=sns.countplot(x="JobSatisfaction", data=hrdata_df, ax=ax[0])
ax1=plt.ylabel("Job_Satisfaction_Count")
ax2=sns.countplot(x="JobInvolvement", data=hrdata_df, ax=ax[1])
ax2=plt.ylabel("Job_Involvement_Count")
#sns.countplot(x="PerformanceRating")
plt.suptitle("Employee Wise Job Satisfaction and Job Involvement Rating")
plt.tight_layout(pad=2.00)
# Out:
# 4    459
# 3    442
# 1    289
# 2    280
# Name: JobSatisfaction, dtype: int64
# 4    0.312245
# 3    0.300680
# 1    0.196599
# 2    0.190476
# Name: JobSatisfaction, dtype: float64
# ...
# 3    868
# 2    375
# 4    144
# 1     83
# Name: JobInvolvement, dtype: int64
# 3    0.590476
# 2    0.255102
# 4    0.097959
# 1    0.056463
# Name: JobInvolvement, dtype: float64
# *****************************************************************************************************************************

# %%
plt.pie(JobSatisfaction_Count, autopct="%.2f", labels=JobSatisfaction_Count.index)
plt.show()

# %%
plt.pie(JobInvolvement_Count,autopct="%.2f", labels=JobInvolvement_Count.index)
plt.show()

# %%
PerformanceRating_Count=hrdata_df['PerformanceRating'].value_counts()
print(PerformanceRating_Count)
print("="*125)
PerformanceRating_Percent=hrdata_df['PerformanceRating'].value_counts(normalize=True)
print(PerformanceRating_Percent)
print("*"*125)

hrdata_df['PerformanceRating'].value_counts().plot(kind='pie', autopct="%.2f",shadow=True,startangle=90,labels=PerformanceRating_Count.index)
plt.show()
# Out:
# 3    1244
# 4     226
# Name: PerformanceRating, dtype: int64
# ...
# 3    0.846259
# 4    0.153741
# Name: PerformanceRating, dtype: float64
# *****************************************************************************************************************************

# %% [markdown]
# # Business Travel Attrition

# %%
BusinessTravel_Wise_Attrition=hrdata_df.groupby(['BusinessTravel'])['Attrition'].value_counts().unstack()
print(BusinessTravel_Wise_Attrition)
BusinessTravel_Wise_Attrition.plot(kind='bar', alpha=1,stacked='False')
ply
# Out:
# Attrition           No  Yes
# BusinessTravel
# Non-Travel         138   12
# Travel_Frequently  208   69
# Travel_Rarely      887  156
# <AxesSubplot: xlabel='BusinessTravel'>

# %% [markdown]
# # Years_Of_Experience

# %%
we=hrdata_df[['YearsAtCompany','YearsSinceLastPromotion', 'YearsWithCurrManager','TotalWorkingYears','Attrition']]
we.head()
# Out:
#    YearsAtCompany  YearsSinceLastPromotion  YearsWithCurrManager  \
# 0               0                        0                     0
# 1               0                        0                     0
# 2               0                        0                     0
# 3               0                        0                     0
# 4               0                        0                     0
#
#    TotalWorkingYears Attrition
# 0                  7       Yes
# 1                  0        No
# 2                 17        No
# 3                  3        No
# 4                  1        No

# %%
YearsAtCompany=hrdata_df.groupby(['YearsAtCompany'])['Attrition'].value_counts().unstack()
print(YearsAtCompany)

YearsAtCompany.plot(kind='bar', stacked='False', figsize=(10,5))
# Out:
# Attrition          No   Yes
# YearsAtCompany
# 0                28.0  16.0
# 1               112.0  59.0
# 2               100.0  27.0
# 3               108.0  20.0
# 4                91.0  19.0
# 5               175.0  21.0
# 6                67.0   9.0
# 7                79.0  11.0
# 8                71.0   9.0
# 9                74.0   8.0
# 10              102.0  18.0
# 11               30.0   2.0
# 12               14.0   NaN
# 13               22.0   2.0
# 14               16.0   2.0
# 15               19.0   1.0
# 16               11.0   1.0
# 17                8.0   1.0
# 18               12.0   1.0
# 19               10.0   1.0
# 20               26.0   1.0
# 21               13.0   1.0
# 22               14.0   1.0
# 23                1.0   1.0
# 24                5.0   1.0
# 25                4.0   NaN
# 26                4.0   NaN
# 27                2.0   NaN
# 29                2.0   NaN
# 30                1.0   NaN
# 31                2.0   1.0
# ...

# %% [markdown]
# # So we can observ the newly arrived employees with less than 10 years are leaving more

# %%
YearsSinceLastPromotion_Wise_Attrition=hrdata_df.groupby(['YearsSinceLastPromotion'])['Attrition'].value_counts().unstack()
print(YearsSinceLastPromotion_Wise_Attrition)
YearsWithCurrManager_Wise_Attrition=hrdata_df.groupby(['YearsWithCurrManager'])['Attrition'].value_counts().unstack()
print(YearsWithCurrManager_Wise_Attrition)


fig=plt.figure()
ax0=fig.add_subplot(121)
ax1=fig.add_subplot(122)
YearsSinceLastPromotion_Wise_Attrition.plot(kind='bar', figsize=(20,6), stacked='False', ax=ax0)
ax0.set_title("Last_Promotion_Wise_Attrition")
ax0.set_xlabel("Years_Since_Last_Promotion")
ax0.set_ylabel("Attrition_Count")
YearsWithCurrManager_Wise_Attrition.plot(kind='bar', figsize=(20,6), stacked='False', ax=ax1)
plt.suptitle("Years_Since_Last_Promotion And Years_With_Curr_Manager Wise Attrition")
ax1.set_title("Years_With_Curr_Manager Wise Attrition")
ax1.set_ylabel("Attrition_Count")
ax1.set_xlabel("Years_With_Curr_Manager")

plt.show()
# Out:
# Attrition                   No    Yes
# YearsSinceLastPromotion
# 0                        471.0  110.0
# 1                        308.0   49.0
# 2                        132.0   27.0
# 3                         43.0    9.0
# 4                         56.0    5.0
# 5                         43.0    2.0
# 6                         26.0    6.0
# 7                         60.0   16.0
# 8                         18.0    NaN
# 9                         13.0    4.0
# 10                         5.0    1.0
# 11                        22.0    2.0
# 12                        10.0    NaN
# 13                         8.0    2.0
# 14                         8.0    1.0
# 15                        10.0    3.0
# Attrition                No   Yes
# YearsWithCurrManager
# 0                     178.0  85.0
# 1                      65.0  11.0
# 2                     294.0  50.0
# 3                     123.0  19.0
# 4                      87.0  11.0
# 5                      27.0   4.0
# ...

# %%
TotalWorkingYears_Wise_Attrition=hrdata_df.groupby(['TotalWorkingYears'])['Attrition'].value_counts().unstack()
print(TotalWorkingYears_Wise_Attrition)

TotalWorkingYears_Wise_Attrition.plot(kind='bar', stacked='False', figsize=(10,5))
plt.title("TotalWorkingYears_Wise_Attrition")
plt.ylabel("Attrition_Count")
# Out:
# Attrition             No   Yes
# TotalWorkingYears
# 0                    6.0   5.0
# 1                   41.0  40.0
# 2                   22.0   9.0
# 3                   33.0   9.0
# 4                   51.0  12.0
# 5                   72.0  16.0
# 6                  103.0  22.0
# 7                   63.0  18.0
# 8                   87.0  16.0
# 9                   86.0  10.0
# 10                 177.0  25.0
# 11                  29.0   7.0
# 12                  43.0   5.0
# 13                  33.0   3.0
# 14                  27.0   4.0
# 15                  35.0   5.0
# 16                  34.0   3.0
# 17                  30.0   3.0
# 18                  23.0   4.0
# 19                  19.0   3.0
# 20                  28.0   2.0
# 21                  33.0   1.0
# 22                  19.0   2.0
# 23                  20.0   2.0
# 24                  15.0   3.0
# 25                  13.0   1.0
# 26                  13.0   1.0
# 27                   7.0   NaN
# ...

# %% [markdown]
# # Monthly Income

# %%
MonthlyIncome_Wise_Attrition=hrdata_df.groupby(['Attrition'])['MonthlyIncome'].sum()
print(MonthlyIncome_Wise_Attrition)
print("="*125)
fig,ax=plt.subplots(1,1,figsize=(10,5))
hrdata_df.groupby(['Attrition'])['MonthlyIncome'].sum().plot(kind='bar')
plt.title("MonthlyIncome_Wise_Attrition")
plt.ylabel("MonthlyIncome")
# Out:
# Attrition
# No     8424768
# Yes    1134541
# Name: MonthlyIncome, dtype: int64
# ...
# Text(0, 0.5, 'MonthlyIncome')

# %% [markdown]
# # OverTime Attrition

# %%
OverTime_Wise_Attrition=hrdata_df.groupby(["OverTime"])['Attrition'].value_counts().unstack()
print(OverTime_Wise_Attrition)

OverTime_Wise_Attrition.plot(kind='bar', stacked='False', figsize=(10,5))
plt.title("Over_Time_Wise_Attrition")
plt.ylabel("OverTime Amount")
# Out:
# Attrition   No  Yes
# OverTime
# No         944  110
# Yes        289  127
# Text(0, 0.5, 'OverTime Amount')

# %% [markdown]
# # Department Attrition

# %%
Department_Count=hrdata_df['Department'].value_counts()
print(Department_Count)
print("="*125)
Department_Percent=hrdata_df['Department'].value_counts(normalize=True)
print(Department_Percent)
print("*"*125)

plt.pie(Department_Count, autopct="%.2f", shadow=True, startangle=50, labels=Department_Count.index)
plt.show()
# Out:
# Research & Development    961
# Sales                     446
# Human Resources            63
# Name: Department, dtype: int64
# ...
# Research & Development    0.653741
# Sales                     0.303401
# Human Resources           0.042857
# Name: Department, dtype: float64
# *****************************************************************************************************************************

# %%
Department_Wise_Attrition=hrdata_df.groupby(['Department'])['Attrition'].value_counts().unstack()
print(Department_Wise_Attrition)

Department_Wise_Attrition.plot(kind='bar', stacked='False', figsize=(10,5))
plt.title("Department_Wise_Attrition")
plt.ylabel("Attrition_Count")
# Out:
# Attrition                No  Yes
# Department
# Human Resources          51   12
# Research & Development  828  133
# Sales                   354   92
# Text(0, 0.5, 'Attrition_Count')

# %% [markdown]
# # Gender  Attrition

# %%
Gender_Count=hrdata_df['Gender'].value_counts()
print(Gender_Count)
print("="*125)
Gender_Percent=hrdata_df['Gender'].value_counts(normalize=True)
print(Gender_Percent)
print("*"*125)
plt.pie(Gender_Count, autopct="%.2f", shadow=True, startangle=50, labels=Gender_Count.index)
plt.show()
# Out:
# Male      882
# Female    588
# Name: Gender, dtype: int64
# ...
# Male      0.6
# Female    0.4
# Name: Gender, dtype: float64
# *****************************************************************************************************************************

# %%
Male_Gender=hrdata_df[hrdata_df['Gender']=='Male']
Female_Gender=hrdata_df[hrdata_df['Gender']=='Female']

# %%
Male_Gender_Wise_Attrition_Count=Male_Gender['Attrition'].value_counts()
Female_Gender_Wise_Attrition_Count=Female_Gender['Attrition'].value_counts()
print("Male_Gender_Wise_Attrition_Count")
print(Male_Gender_Wise_Attrition_Count)
print("-"*125)
print("Female_Gender_Wise_Attrition_Count")
print(Female_Gender_Wise_Attrition_Count)
print("="*125)
Male_Gender_Wise_Attrition_Percent=Male_Gender['Attrition'].value_counts(normalize=True)
Female_Gender_Wise_Attrition_Percent=Female_Gender['Attrition'].value_counts(normalize=True)
print("Male_Gender_Wise_Attrition_Percent")
print(Male_Gender_Wise_Attrition_Percent)
print("-"*125)
print("Female_Gender_Wise_Attrition_Percent")
print(Female_Gender_Wise_Attrition_Percent)
# Out:
# Male_Gender_Wise_Attrition_Count
# No     732
# Yes    150
# Name: Attrition, dtype: int64
# -----------------------------------------------------------------------------------------------------------------------------
# Female_Gender_Wise_Attrition_Count
# No     501
# Yes     87
# Name: Attrition, dtype: int64
# ...
# Male_Gender_Wise_Attrition_Percent
# No     0.829932
# Yes    0.170068
# Name: Attrition, dtype: float64
# -----------------------------------------------------------------------------------------------------------------------------
# Female_Gender_Wise_Attrition_Percent
# No     0.852041
# Yes    0.147959
# Name: Attrition, dtype: float64

# %%
fig=plt.figure()
ax0=fig.add_subplot(121)
ax1=fig.add_subplot(122)
Male_Gender_Wise_Attrition_Count.plot(kind='bar', figsize=(10,5), ax=ax0)
ax0.set_xlabel("Male_Gender_Wise_Attrition_Count")
ax0.set_ylabel("Attrition_Count")
ax0.set_title("Male_Gender_Wise_Attrition")
Female_Gender_Wise_Attrition_Count.plot(kind='bar', figsize=(10,5), ax=ax1)
ax1.set_xlabel("Female_Gender_Wise_Attrition_Count")
ax1.set_ylabel("Attrition_Count")
ax1.set_title("Female_Gender_Wise_Attrition")
# Out:
# Text(0.5, 1.0, 'Female_Gender_Wise_Attrition')

# %% [markdown]
# # Marital Status Attrition

# %%
Gender_Count=hrdata_df['MaritalStatus'].value_counts()
print(Gender_Count)
print("="*125)
Gender_Percent=hrdata_df['MaritalStatus'].value_counts(normalize=True)
print(Gender_Percent)
print("*"*125)
plt.pie(Gender_Count, autopct="%.2f", shadow=True, startangle=50, labels=Gender_Count.index)
plt.show()
# Out:
# Married     673
# Single      470
# Divorced    327
# Name: MaritalStatus, dtype: int64
# ...
# Married     0.457823
# Single      0.319728
# Divorced    0.222449
# Name: MaritalStatus, dtype: float64
# *****************************************************************************************************************************

# %%
Single_People=hrdata_df[hrdata_df['MaritalStatus']=='Single']
Married_People=hrdata_df[hrdata_df['MaritalStatus']=='Married']
Divorced_People=hrdata_df[hrdata_df['MaritalStatus']=='Divorced']

# %%
Single_People_Wise_Attrition=Single_People['Attrition'].value_counts()
Married_People_Wise_Attrition=Married_People['Attrition'].value_counts()
Divorced_People_Wise_Attrition=Divorced_People['Attrition'].value_counts()
print(Single_People_Wise_Attrition)
print("Single_People_Wise_Attrition")
print("-"*125)
print("Married_People_Wise_Attrition")
print(Married_People_Wise_Attrition)
print("-"*125)
print("Divorced_People_Wise_Attrition")
print(Divorced_People_Wise_Attrition)
print("="*125)
# Out:
# No     350
# Yes    120
# Name: Attrition, dtype: int64
# Single_People_Wise_Attrition
# -----------------------------------------------------------------------------------------------------------------------------
# Married_People_Wise_Attrition
# No     589
# Yes     84
# Name: Attrition, dtype: int64
# -----------------------------------------------------------------------------------------------------------------------------
# Divorced_People_Wise_Attrition
# No     294
# Yes     33
# Name: Attrition, dtype: int64
# ...

# %%
fig=plt.figure()
ax0=fig.add_subplot(121)
ax1=fig.add_subplot(122)
Single_People_Wise_Attrition.plot(kind='bar', figsize=(10,5), ax=ax0)
ax0.set_xlabel("Single_People_Wise_Attrition_Count")
ax0.set_ylabel("Attrition_Count")
ax0.set_title("Single_People_Wise_Attrition")
Married_People_Wise_Attrition.plot(kind='bar', figsize=(10,5), ax=ax1)
ax1.set_xlabel("Married_People_Wise_Attrition_Count")
ax1.set_ylabel("Attrition_Count")
ax1.set_title("Married_People_Wise_Attrition")
# Out:
# Text(0.5, 1.0, 'Married_People_Wise_Attrition')

# %%
Divorced_People_Wise_Attrition.plot(kind='bar')
plt.title("Divorced_People_Wise_Attrition_Count")
plt.ylabel("Divorced_People_Wise_Attrition")
plt.xlabel("Attrition")
# Out:
# Text(0.5, 0, 'Attrition')

# %% [markdown]
# # Conclusion
# ->From The above analysis it can be observed that:
#     =>There are few number of people who is leaving the company
#
# When it comes to rating:
# =>Many of the employee has poor job satisfaction rating which means there are few employee who is not satisfied with their job
#
# =>Many of the employee has poor job involvement rating which means there are few employee who is not very much involved or satisfied in their job role or with their job
#
# =>Almost 80% of the employee also cannot perform very well and have a low performance rating
#
# =>From the above graph it is clear that the employees who travel very rarely has more attitiion rate than the employees who travel very frequently
#
# => Best way is to reduce the attrition is to conduct a monthly campaign and allot travel according to Employees business travel interest
#
# =>Many of the employees who have recently joined the company or employees having less than 10years of work experience is more towards attrition
#
# =>Many of the employees who have not being promoted is more tending to leave the company. So the company must look towards employee attrtion
#
# =>Many of the employees who came newly under a manager is more tending to leave the company
#
# =>Many of the employees almost the fresher is more towards attrition
#
# =>Male genders are more towards attrition than female genders
#
# =>Single people are tending more towards attrition the married and divorced people
#
# =>More people are leaving from Research and Development Department as compared to Sales and Human Resource
